# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
ipl=pd.read_csv("C:/Users/Acer/Desktop/Data sets/Matches IPL 2020.csv")

# %%
ipl
# Out:
#          id  season         city        date team1 team2 toss_winner  \
# 0   1216492    2020    Abu Dhabi  09/19/2020    MI   CSK         CSK
# 1   1216493    2020  Dubai (DSC)  09/20/2020    DC  KXIP        KXIP
# 2   1216534    2020  Dubai (DSC)  09/21/2020   SRH   RCB         SRH
# 3   1216496    2020      Sharjah  09/22/2020    RR   CSK         CSK
# 4   1216508    2020    Abu Dhabi  09/23/2020   KKR    MI         KKR
# 5   1216510    2020  Dubai (DSC)  09/24/2020  KXIP   RCB         RCB
# 6   1216539    2020  Dubai (DSC)  09/25/2020   CSK    DC         CSK
# 7   1216545    2020    Abu Dhabi  09/26/2020   KKR   SRH         SRH
# 8   1216527    2020      Sharjah  09/27/2020    RR  KXIP          RR
# 9   1216547    2020  Dubai (DSC)  09/28/2020   RCB    MI          MI
# 10  1216532    2020    Abu Dhabi  09/29/2020    DC   SRH          DC
# 11  1216504    2020  Dubai (DSC)  09/30/2020    RR   KKR          RR
# 12  1216503    2020    Abu Dhabi    10-01-20  KXIP    MI        KXIP
# 13  1216516    2020  Dubai (DSC)    10-02-20   CSK   SRH         SRH
# 14  1216514    2020    Abu Dhabi    10-03-20   RCB    RR          RR
# 15  1216515    2020      Sharjah    10-03-20    DC   KKR         KKR
# 16  1216538    2020      Sharjah    10-04-20    MI   SRH          MI
# 17  1216513    2020  Dubai (DSC)    10-04-20  KXIP   CSK        KXIP
# 18  1216519    2020  Dubai (DSC)    10-05-20   RCB    DC         RCB
# 19  1216511    2020    Abu Dhabi    10-06-20    MI    RR          MI
# 20  1216501    2020    Abu Dhabi    10-07-20   KKR   CSK         KKR
# 21  1216542    2020  Dubai (DSC)    10-08-20   SRH  KXIP         SRH
# 22  1216500    2020      Sharjah    10-09-20    RR    DC          RR
# 23  1216523    2020    Abu Dhabi    10-10-20  KXIP   KKR         KKR
# 24  1216525    2020  Dubai (DSC)    10-10-20   CSK   RCB         RCB
# 25  1216507    2020  Dubai (DSC)    10-11-20   SRH    RR         SRH
# 26  1216529    2020    Abu Dhabi    10-11-20    MI    DC          DC
# 27  1216540    2020      Sharjah    10-12-20   RCB   KKR         RCB
# 28  1216528    2020  Dubai (DSC)  10-13-2020   SRH   CSK         CSK
# 29  1216543    2020  Dubai (DSC)  10-14-2020    DC    RR          DC
# 30  1216531    2020      Sharjah  10-15-2020   RCB  KXIP         RCB
# 31  1216526    2020    Abu Dhabi  10-16-2020    MI   KKR         KKR
# 32  1216522    2020  Dubai (DSC)  10-17-2020    RR   RCB          RR
# 33  1216509    2020      Sharjah  10-17-2020    DC   CSK         CSK
# 34  1216512    2020    Abu Dhabi  10-18-2020   SRH   KKR         SRH
# 35  1216517    2020  Dubai (DSC)  10-18-2020    MI  KXIP          MI
# 36  1216533    2020    Abu Dhabi  10-19-2020   CSK    RR         CSK
# 37  1216546    2020  Dubai (DSC)  10-20-2020  KXIP    DC          DC
# 38  1216494    2020    Abu Dhabi  10-21-2020   KKR   RCB         KKR
# 39  1216518    2020  Dubai (DSC)  10-22-2020    RR   SRH         SRH
# 40  1216521    2020      Sharjah  10-23-2020   CSK    MI          MI
# 41  1216497    2020    Abu Dhabi  10-24-2020   KKR    DC          DC
# 42  1216498    2020  Dubai (DSC)  10-24-2020  KXIP   SRH         SRH
# 43  1216544    2020  Dubai (DSC)  10-25-2020   RCB   CSK         RCB
# 44  1216541    2020    Abu Dhabi  10-25-2020    RR    MI          MI
# 45  1216520    2020      Sharjah  10-26-2020   KKR  KXIP        KXIP
# 46  1216524    2020  Dubai (DSC)  10-27-2020   SRH    DC          DC
# 47  1216499    2020    Abu Dhabi  10-28-2020    MI   RCB          MI
# 48  1216536    2020  Dubai (DSC)  10-29-2020   CSK   KKR         CSK
# 49  1216537    2020    Abu Dhabi  10-30-2020  KXIP    RR          RR
# 50  1216535    2020  Dubai (DSC)  10-31-2020    DC    MI          MI
# 51  1216502    2020      Sharjah  10-31-2020   RCB   SRH         SRH
# 52  1216506    2020    Abu Dhabi    11-01-20   CSK  KXIP         CSK
# 53  1216530    2020  Dubai (DSC)    11-01-20   KKR    RR          RR
# 54  1216505    2020    Abu Dhabi    11-02-20    DC   RCB          DC
# 55  1216495    2020      Sharjah    11-03-20   SRH    MI         SRH
# 56  1237177    2020  Dubai (DSC)    11-05-20    DC    MI          DC
# 57  1237178    2020    Abu Dhabi    11-06-20   RCB   SRH         SRH
# 58  1237180    2020    Abu Dhabi    11-08-20    DC   SRH          DC
# 59  1237181    2020  Dubai (DSC)    11-10-20    DC    MI          DC
#
#    toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0          field  normal           0    CSK            0               5
# 1          field     tie           0     DC            0               0
# 2          field  normal           0    RCB           10               0
# 3          field  normal           0     RR           16               0
# 4          field  normal           0     MI           49               0
# 5          field  normal           0   KXIP           97               0
# 6          field  normal           0     DC           44               0
# 7            bat  normal           0    KKR            0               7
# 8          field  normal           0     RR            0               4
# 9          field     tie           0    RCB            0               0
# 10         field  normal           0    SRH           15               0
# 11         field  normal           0    KKR           37               0
# 12         field  normal           0     MI           48               0
# 13           bat  normal           0    SRH            7               0
# 14           bat  normal           0    RCB            0               8
# 15         field  normal           0     DC           18               0
# 16           bat  normal           0     MI           34               0
# 17           bat  normal           0    CSK            0              10
# 18         field  normal           0     DC           59               0
# 19           bat  normal           0     MI           57               0
# 20           bat  normal           0    KKR           10               0
# 21           bat  normal           0    SRH           69               0
# 22         field  normal           0     DC           46               0
# 23           bat  normal           0    KKR            2               0
# 24           bat  normal           0    RCB           37               0
# 25           bat  normal           0     RR            0               5
# 26           bat  normal           0     MI            0               5
# 27           bat  normal           0    RCB           82               0
# 28           bat  normal           0    CSK           20               0
# 29           bat  normal           0     DC           13               0
# 30           bat  normal           0   KXIP            0               8
# 31           bat  normal           0     MI            0               8
# 32           bat  normal           0    RCB            0               7
# 33           bat  normal           0     DC            0               5
# 34         field     tie           0    KKR            0               0
# 35           bat     tie           0   KXIP            0               0
# 36           bat  normal           0     RR            0               7
# 37           bat  normal           0   KXIP            0               5
# 38           bat  normal           0    RCB            0               8
# 39         field  normal           0    SRH            0               8
# 40         field  normal           0     MI            0              10
# 41         field  normal           0    KKR           59               0
# 42         field  normal           0   KXIP           12               0
# 43           bat  normal           0    CSK            0               8
# 44           bat  normal           0     RR            0               8
# 45         field  normal           0   KXIP            0               8
# 46         field  normal           0    SRH           88               0
# 47         field  normal           0     MI            0               5
# 48         field  normal           0    CSK            0               6
# 49         field  normal           0     RR            0               7
# 50         field  normal           0     MI            0               9
# 51         field  normal           0    SRH            0               5
# 52         field  normal           0    CSK            0               9
# 53         field  normal           0    KKR           60               0
# 54         field  normal           0     DC            0               6
# 55         field  normal           0    SRH            0              10
# 56         field  normal           0     MI           57               0
# 57         field  normal           0    SRH            0               6
# 58           bat  normal           0     DC           17               0
# 59           bat  normal           0     MI            0               5
#
#     player_of_match                                venue  \
# 0         AT Rayudu      Sheikh Zayed Stadium, Abu Dhabi
# 1        MP Stoinis  Dubai International Cricket Stadium
# 2         YS Chahal  Dubai International Cricket Stadium
# 3         SV Samson              Sharjah Cricket Stadium
# 4         RG Sharma      Sheikh Zayed Stadium, Abu Dhabi
# 5          KL Rahul  Dubai International Cricket Stadium
# 6            P Shaw  Dubai International Cricket Stadium
# 7      Shubman Gill      Sheikh Zayed Stadium, Abu Dhabi
# 8         SV Samson              Sharjah Cricket Stadium
# 9    AB de Villiers  Dubai International Cricket Stadium
# 10      Rashid Khan      Sheikh Zayed Stadium, Abu Dhabi
# 11      Shivam Mavi  Dubai International Cricket Stadium
# 12       KA Pollard      Sheikh Zayed Stadium, Abu Dhabi
# 13      Priyam Garg  Dubai International Cricket Stadium
# 14        YS Chahal      Sheikh Zayed Stadium, Abu Dhabi
# 15          SS Iyer              Sharjah Cricket Stadium
# 16         TA Boult              Sharjah Cricket Stadium
# 17        SR Watson  Dubai International Cricket Stadium
# 18        AR  Patel  Dubai International Cricket Stadium
# 19         AS Yadav      Sheikh Zayed Stadium, Abu Dhabi
# 20      RA Tripathi      Sheikh Zayed Stadium, Abu Dhabi
# 21       J Bairstow  Dubai International Cricket Stadium
# 22         R Ashwin              Sharjah Cricket Stadium
# 23       KD Karthik      Sheikh Zayed Stadium, Abu Dhabi
# 24          V Kohli  Dubai International Cricket Stadium
# 25        R Tewatia  Dubai International Cricket Stadium
# 26        Q de Kock      Sheikh Zayed Stadium, Abu Dhabi
# 27   AB de Villiers              Sharjah Cricket Stadium
# 28        RA Jadeja  Dubai International Cricket Stadium
# 29    Anrich Nortje  Dubai International Cricket Stadium
# 30         KL Rahul              Sharjah Cricket Stadium
# 31        Q de Kock      Sheikh Zayed Stadium, Abu Dhabi
# 32   AB de Villiers  Dubai International Cricket Stadium
# 33         S Dhawan              Sharjah Cricket Stadium
# 34       L Ferguson      Sheikh Zayed Stadium, Abu Dhabi
# 35         KL Rahul  Dubai International Cricket Stadium
# 36       JC Buttler      Sheikh Zayed Stadium, Abu Dhabi
# 37         S Dhawan  Dubai International Cricket Stadium
# 36           Chris Gaffaney            Virender Sharma
# 37  Chettithody Shamshuddin        Richard Illingworth
# 38          Virender Sharma              Sundaram Ravi
# 39              Nitin Menon               Paul Reiffel
# 40  Chettithody Shamshuddin            Vineet Kulkarni
# 41           Chris Gaffaney            Pashchim Pathak
# 42            Anil Dandekar               Paul Reiffel
# 43  Chettithody Shamshuddin        Richard Illingworth
# 44             Ulhas Gandhe            Virender Sharma
# 45    KN Ananthapadmanabhan        Richard Illingworth
# 46           Anil Chaudhary                Nitin Menon
# 47             Ulhas Gandhe             Chris Gaffaney
# 48  Chettithody Shamshuddin        Richard Illingworth
# 49           Chris Gaffaney              Sundaram Ravi
# 50           Yeshwant Barde               Paul Reiffel
# 51    KN Ananthapadmanabhan  Krishnamachari Srinivasan
# 52          Pashchim Pathak            Virender Sharma
# 53              Nitin Menon               Paul Reiffel
# 54           Chris Gaffaney              Sundaram Ravi
# 55  Chettithody Shamshuddin        Richard Illingworth
# 56           Chris Gaffaney                Nitin Menon
# 57             Paul Reiffel              Sundaram Ravi
# 58             Paul Reiffel              Sundaram Ravi
# 59           Chris Gaffaney                Nitin Menon
#
#                       umpire3
# 0               Sundaram Ravi
# 1                Paul Reiffel
# 2              Anil Chaudhary
# 3       KN Ananthapadmanabhan
# 4             Virender Sharma
# 5                 Nitin Menon
# 6   Krishnamachari Srinivasan
# 7               Sundaram Ravi
# 8     Chettithody Shamshuddin
# 9              Anil Chaudhary
# 10             Chris Gaffaney
# 11            Vineet Kulkarni
# 12               Ulhas Gandhe
# 13             Yeshwant Barde
# 14            Pashchim Pathak
# 15      KN Ananthapadmanabhan
# 16  Krishnamachari Srinivasan
# 17               Paul Reiffel
# 18               Paul Reiffel
# 19             Chris Gaffaney
# 20    Chettithody Shamshuddin
# 21             Yeshwant Barde
# 22            Vineet Kulkarni
# 23            Virender Sharma
# 24              Anil Dandekar
# 25                Nitin Menon
# 26            Virender Sharma
# 27      KN Ananthapadmanabhan
# 28                Nitin Menon
# 29              Anil Dandekar
# 30        Richard Illingworth
# 31              Sundaram Ravi
# 32               Paul Reiffel
# 33    Chettithody Shamshuddin
# 34            Virender Sharma
# 35             Anil Chaudhary
# 36               Ulhas Gandhe
# 37      KN Ananthapadmanabhan
# 38             Chris Gaffaney
# 39             Anil Chaudhary
# 40        Richard Illingworth
# 41              Sundaram Ravi
# 42                Nitin Menon
# 43      KN Ananthapadmanabhan
# 44              Sundaram Ravi
# 45  Krishnamachari Srinivasan
# 46               Paul Reiffel
# 47              Sundaram Ravi
# 48      KN Ananthapadmanabhan
# 49            Pashchim Pathak
# 50             Anil Chaudhary
# 51    Chettithody Shamshuddin
# 52             Chris Gaffaney
# 53             Anil Chaudhary
# 54            Virender Sharma
# 55      KN Ananthapadmanabhan
# 56      KN Ananthapadmanabhan
# 57            Virender Sharma
# 58    Chettithody Shamshuddin
# 59             Anil Chaudhary

# %%
ipl.head()
# Out:
#         id  season         city        date team1 team2 toss_winner  \
# 0  1216492    2020    Abu Dhabi  09/19/2020    MI   CSK         CSK
# 1  1216493    2020  Dubai (DSC)  09/20/2020    DC  KXIP        KXIP
# 2  1216534    2020  Dubai (DSC)  09/21/2020   SRH   RCB         SRH
# 3  1216496    2020      Sharjah  09/22/2020    RR   CSK         CSK
# 4  1216508    2020    Abu Dhabi  09/23/2020   KKR    MI         KKR
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    CSK            0               5
# 1         field     tie           0     DC            0               0
# 2         field  normal           0    RCB           10               0
# 3         field  normal           0     RR           16               0
# 4         field  normal           0     MI           49               0
#
#   player_of_match                                venue  \
# 0       AT Rayudu      Sheikh Zayed Stadium, Abu Dhabi
# 1      MP Stoinis  Dubai International Cricket Stadium
# 2       YS Chahal  Dubai International Cricket Stadium
# 3       SV Samson              Sharjah Cricket Stadium
# 4       RG Sharma      Sheikh Zayed Stadium, Abu Dhabi
#
#                    umpire1          umpire2                umpire3
# 0           Chris Gaffaney  Virender Sharma          Sundaram Ravi
# 1           Anil Chaudhary      Nitin Menon           Paul Reiffel
# 2            Anil Dandekar      Nitin Menon         Anil Chaudhary
# 3  Chettithody Shamshuddin  Vineet Kulkarni  KN Ananthapadmanabhan
# 4           Chris Gaffaney    Sundaram Ravi        Virender Sharma

# %% [markdown]
# # Shape of the data set

# %%
ipl.shape
# Out:
# (60, 18)

# %% [markdown]
# # Frequency of most MOM Awards

# %%
ipl["player_of_match"].value_counts()
# Out:
# AB de Villiers     3
# TA Boult           3
# KL Rahul           3
# RD Gaikwad         3
# BA Stokes          2
# Q de Kock          2
# Anrich Nortje      2
# S Dhawan           2
# YS Chahal          2
# AS Yadav           2
# MP Stoinis         2
# SV Samson          2
# CH Gayle           1
# L Ferguson         1
# S Nadeem           1
# RA Tripathi        1
# Abhishek Sharma    1
# KS Williamson      1
# CJ Jordan          1
# AR  Patel          1
# CV Varun           1
# RG Sharma          1
# AT Rayudu          1
# R Ashwin           1
# V Kohli            1
# JC Buttler         1
# R Tewatia          1
# SR Watson          1
# PJ Cummins         1
# Priyam Garg        1
# KA Pollard         1
# RA Jadeja          1
# J Bairstow         1
# Shubman Gill       1
# WP Saha            1
# Rashid Khan        1
# JJ Bumrah          1
# Shivam Mavi        1
# KD Karthik         1
# P Shaw             1
# Ishan Kishan       1
# MK Pandey          1
# SS Iyer            1
# Mohammed Siraj     1
# Name: player_of_match, dtype: int64

# %%
ipl["player_of_match"].value_counts()[0:10]
# Out:
# AB de Villiers    3
# TA Boult          3
# KL Rahul          3
# RD Gaikwad        3
# BA Stokes         2
# Q de Kock         2
# Anrich Nortje     2
# S Dhawan          2
# YS Chahal         2
# AS Yadav          2
# Name: player_of_match, dtype: int64

# %%
plt.figure(figsize=(20,11))
plt.bar(list(ipl["player_of_match"].value_counts()[0:10].keys()),list(ipl["player_of_match"].value_counts()[0:10]),color='g')
# Out:
# <BarContainer object of 10 artists>

# %%
ipl['result'].value_counts()
# Out:
# normal    56
# tie        4
# Name: result, dtype: int64

# %%
ipl['toss_winner'].value_counts()
# Out:
# SRH     11
# DC      10
# MI       8
# CSK      8
# RR       7
# KKR      6
# RCB      6
# KXIP     4
# Name: toss_winner, dtype: int64

# %%
batting_first=ipl[ipl['win_by_runs']!=0]

# %%
batting_first
# Out:
#          id  season         city        date team1 team2 toss_winner  \
# 2   1216534    2020  Dubai (DSC)  09/21/2020   SRH   RCB         SRH
# 3   1216496    2020      Sharjah  09/22/2020    RR   CSK         CSK
# 4   1216508    2020    Abu Dhabi  09/23/2020   KKR    MI         KKR
# 5   1216510    2020  Dubai (DSC)  09/24/2020  KXIP   RCB         RCB
# 6   1216539    2020  Dubai (DSC)  09/25/2020   CSK    DC         CSK
# 10  1216532    2020    Abu Dhabi  09/29/2020    DC   SRH          DC
# 11  1216504    2020  Dubai (DSC)  09/30/2020    RR   KKR          RR
# 12  1216503    2020    Abu Dhabi    10-01-20  KXIP    MI        KXIP
# 13  1216516    2020  Dubai (DSC)    10-02-20   CSK   SRH         SRH
# 15  1216515    2020      Sharjah    10-03-20    DC   KKR         KKR
# 16  1216538    2020      Sharjah    10-04-20    MI   SRH          MI
# 18  1216519    2020  Dubai (DSC)    10-05-20   RCB    DC         RCB
# 19  1216511    2020    Abu Dhabi    10-06-20    MI    RR          MI
# 20  1216501    2020    Abu Dhabi    10-07-20   KKR   CSK         KKR
# 21  1216542    2020  Dubai (DSC)    10-08-20   SRH  KXIP         SRH
# 22  1216500    2020      Sharjah    10-09-20    RR    DC          RR
# 23  1216523    2020    Abu Dhabi    10-10-20  KXIP   KKR         KKR
# 24  1216525    2020  Dubai (DSC)    10-10-20   CSK   RCB         RCB
# 27  1216540    2020      Sharjah    10-12-20   RCB   KKR         RCB
# 28  1216528    2020  Dubai (DSC)  10-13-2020   SRH   CSK         CSK
# 29  1216543    2020  Dubai (DSC)  10-14-2020    DC    RR          DC
# 41  1216497    2020    Abu Dhabi  10-24-2020   KKR    DC          DC
# 42  1216498    2020  Dubai (DSC)  10-24-2020  KXIP   SRH         SRH
# 46  1216524    2020  Dubai (DSC)  10-27-2020   SRH    DC          DC
# 53  1216530    2020  Dubai (DSC)    11-01-20   KKR    RR          RR
# 56  1237177    2020  Dubai (DSC)    11-05-20    DC    MI          DC
# 58  1237180    2020    Abu Dhabi    11-08-20    DC   SRH          DC
#
#    toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 2          field  normal           0    RCB           10               0
# 3          field  normal           0     RR           16               0
# 4          field  normal           0     MI           49               0
# 5          field  normal           0   KXIP           97               0
# 6          field  normal           0     DC           44               0
# 10         field  normal           0    SRH           15               0
# 11         field  normal           0    KKR           37               0
# 12         field  normal           0     MI           48               0
# 13           bat  normal           0    SRH            7               0
# 15         field  normal           0     DC           18               0
# 16           bat  normal           0     MI           34               0
# 18         field  normal           0     DC           59               0
# 19           bat  normal           0     MI           57               0
# 20           bat  normal           0    KKR           10               0
# 21           bat  normal           0    SRH           69               0
# 22         field  normal           0     DC           46               0
# 23           bat  normal           0    KKR            2               0
# 24           bat  normal           0    RCB           37               0
# 27           bat  normal           0    RCB           82               0
# 28           bat  normal           0    CSK           20               0
# 29           bat  normal           0     DC           13               0
# 58             Paul Reiffel              Sundaram Ravi
#
#                       umpire3
# 2              Anil Chaudhary
# 3       KN Ananthapadmanabhan
# 4             Virender Sharma
# 5                 Nitin Menon
# 6   Krishnamachari Srinivasan
# 10             Chris Gaffaney
# 11            Vineet Kulkarni
# 12               Ulhas Gandhe
# 13             Yeshwant Barde
# 15      KN Ananthapadmanabhan
# 16  Krishnamachari Srinivasan
# 18               Paul Reiffel
# 19             Chris Gaffaney
# 20    Chettithody Shamshuddin
# 21             Yeshwant Barde
# 22            Vineet Kulkarni
# 23            Virender Sharma
# 24              Anil Dandekar
# 27      KN Ananthapadmanabhan
# 28                Nitin Menon
# 29              Anil Dandekar
# 41              Sundaram Ravi
# 42                Nitin Menon
# 46               Paul Reiffel
# 53             Anil Chaudhary
# 56      KN Ananthapadmanabhan
# 58    Chettithody Shamshuddin

# %%
plt.figure(figsize=(5,5))
plt.hist(batting_first['win_by_runs'])
plt.title("DISTRIBUTION OF RUNS")
plt.xlabel('RUNS')
# Out:
# Text(0.5, 0, 'RUNS')

# %%
batting_first['winner'].value_counts()
# Out:
# DC      6
# KKR     5
# MI      5
# SRH     4
# RCB     3
# KXIP    2
# CSK     1
# RR      1
# Name: winner, dtype: int64

# %%
plt.figure(figsize=(5,5))
plt.bar(list(batting_first['winner'].value_counts()[0:3].keys()),list(batting_first['winner'].value_counts()[0:3]),color=["blue","yellow","orange"])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.figure(figsize=(6,6))
plt.pie(list(batting_first['winner'].value_counts()),labels=list(batting_first['winner'].value_counts().keys()),autopct='%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2a6caf1dcd0>,
#   <matplotlib.patches.Wedge at 0x2a6caf1d490>,
#   <matplotlib.patches.Wedge at 0x2a6cb053e20>,
#   <matplotlib.patches.Wedge at 0x2a6cb053c10>,
#   <matplotlib.patches.Wedge at 0x2a6cb053eb0>,
#   <matplotlib.patches.Wedge at 0x2a6cb032730>,
#   <matplotlib.patches.Wedge at 0x2a6cb0327c0>,
#   <matplotlib.patches.Wedge at 0x2a6cc59edf0>],
#  [Text(0.8426488837530798, 0.7070663750382201, 'DC'),
#   Text(-0.4356877338869098, 1.0100377213453415, 'KKR'),
#   Text(-1.0999999999999988, 5.1494716492391794e-08, 'MI'),
#   Text(-0.5500000594609761, -0.9526279098330696, 'SRH'),
#   Text(0.31548349660181213, -1.053788481324357, 'RCB'),
#   Text(0.8426488506529125, -0.707066414485461, 'KXIP'),
#   Text(1.0336618642738102, -0.37622220873573, 'CSK'),
#   Text(1.0925621874272575, -0.12770225763143894, 'RR')],
#  [Text(0.4596266638653162, 0.3856725682026655, '22.2%'),
#   Text(-0.2376478548474053, 0.550929666188368, '18.5%'),
#   Text(-0.5999999999999993, 2.808802717766825e-08, '18.5%'),
#   Text(-0.3000000324332597, -0.5196152235453106, '14.8%'),
#   Text(0.17208190723735203, -0.5747937170860128, '11.1%'),
#   Text(0.45962664581067947, -0.3856725897193423, '7.4%'),
#   Text(0.5638155623311691, -0.2052121138558527, '3.7%'),
#   Text(0.5959430113239585, -0.06965577688987579, '3.7%')])
